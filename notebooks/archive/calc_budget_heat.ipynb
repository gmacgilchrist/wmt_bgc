# %% [markdown]
# # Heat budget calculation
# Close the heat budget on the native grid

# %%
import xarray as xr
# %matplotlib inline

# %%
rootdir = '/archive/oar.gfdl.cmip6/ESM4/DECK/ESM4_piControl_D/gfdl.ncrc4-intel16-prod-openmp/pp/'
datadir = 'ocean_annual/av/annual_10yr/'
filename = 'ocean_annual.0941-0950.ann.nc'
ds = xr.open_dataset(rootdir+datadir+filename)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /nbhome/gam/miniconda/envs/mom6/lib/python3.7/site-packages/xarray/backends/file_manager.py in acquire(self, needs_lock)
#     166             try:
# --> 167                 file = self._cache[self._key]
#     168             except KeyError:
#
# /nbhome/gam/miniconda/envs/mom6/lib/python3.7/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      41         with self._lock:
# ---> 42             value = self._cache[key]
#      43             self._cache.move_to_end(key)
#
# KeyError: [<function _open_netcdf4_group at 0x2b8807987488>, ('/archive/oar.gfdl.cmip6/ESM4/DECK/ESM4_piControl_D/gfdl.ncrc4-intel16-prod-openmp/pp/ocean_annual/av/annual_10yr/ocean_annual.0941-0950.ann.nc', CombinedLock([<SerializableLock: 64d4d927-72b1-4a78-84bc-d97a6e32a3ea>, <SerializableLock: 359037ea-cf34-406e-9e6c-c1993817b3e4>])), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('group', None), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /nbhome/gam/miniconda/envs/mom6/lib/python3.7/site-packages/xarray/backends/file_manager.py in acquire(self, needs_lock)
#     172                     kwargs['mode'] = self._mode
# --> 173                 file = self._opener(*self._args, **kwargs)
#     174                 if self._mode == 'w':
#
# /nbhome/gam/miniconda/envs/mom6/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in _open_netcdf4_group(filename, lock, mode, group, **kwargs)
#     243
# --> 244     ds = nc4.Dataset(filename, mode=mode, **kwargs)
#     245
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# OSError: [Errno -51] NetCDF: Unknown file format: b'/archive/oar.gfdl.cmip6/ESM4/DECK/ESM4_piControl_D/gfdl.ncrc4-intel16-prod-openmp/pp/ocean_annual/av/annual_10yr/ocean_annual.0941-0950.ann.nc'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-793e6b194ede> in <module>
#       2 datadir = 'ocean_annual/av/annual_10yr/'
#       3 filename = 'ocean_annual.0941-0950.ann.nc'
# ----> 4 ds = xr.open_dataset(rootdir+datadir+filename)
#
# /nbhome/gam/miniconda/envs/mom6/lib/python3.7/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime)
#     361         if engine == 'netcdf4':
#     362             store = backends.NetCDF4DataStore.open(
# --> 363                 filename_or_obj, group=group, lock=lock, **backend_kwargs)
#     364         elif engine == 'scipy':
#     365             store = backends.ScipyDataStore(filename_or_obj, **backend_kwargs)
#
# /nbhome/gam/miniconda/envs/mom6/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     350             kwargs=dict(group=group, clobber=clobber, diskless=diskless,
#     351                         persist=persist, format=format))
# --> 352         return cls(manager, lock=lock, autoclose=autoclose)
#     353
#     354     @property
#
# /nbhome/gam/miniconda/envs/mom6/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in __init__(self, manager, lock, autoclose)
#     309
#     310         self._manager = manager
# --> 311         self.format = self.ds.data_model
#     312         self._filename = self.ds.filepath()
#     313         self.is_remote = is_remote_uri(self._filename)
#
# /nbhome/gam/miniconda/envs/mom6/lib/python3.7/site-packages/xarray/backends/netCDF4_.py in ds(self)
#     354     @property
#     355     def ds(self):
# --> 356         return self._manager.acquire().value
#     357
#     358     def open_store_variable(self, name, var):
#
# /nbhome/gam/miniconda/envs/mom6/lib/python3.7/site-packages/xarray/backends/file_manager.py in acquire(self, needs_lock)
#     171                     kwargs = kwargs.copy()
#     172                     kwargs['mode'] = self._mode
# --> 173                 file = self._opener(*self._args, **kwargs)
#     174                 if self._mode == 'w':
#     175                     # ensure file doesn't get overriden when opened again
#
# KeyboardInterrupt:

# %% [markdown]
# #### Temperature
#
# [degC]
#
# Potential temperature: `thetao` (x,y,z)

# %% [markdown]
# #### Surface heat fluxes
# [W m^-2]
#
# Outgoing longwave: `rlntds` (x,y)
# Incoming shortwave: `rsdo` (x,y,z)
# Sensible: `hfsso` (x,y)
# Latent: `hflso` (x,y)

# %% [markdown]
# #### Bottom boundary heat flux
# [W m^-2]
#
# Geothermal: `hfgeou` (x,y,z)

# %% [markdown]
# #### Advective heat flux (by residual mean)
#
# [W m^-2]
#
# Zonal flux: `T_adx` (x,y,z)
# Meridional flux: `T_ady` (x,y,z)

# %% [markdown]
# #### Diffusive heat flux
#
# [W m^-2]
#
# Zonal flux: `T_diffx` (x,y,z)
# Meridional flux: `T_diffy` (x,y,z)
#
# Heat flux due to parameterized mesoscale diffusion: `T_dfxy_cont_tendency` (x,y,z)
# Temperature tendency due to parameterized mesoscale diffusion `T_dfxy_conc_tendency` (x,y,z) [degC s^-1]

# %% [markdown]
# #### Vertical remap
#
# Temperature tendency due to remap: `T_tendency_vert_remap` (x,y,z) [degC s^-1]
#
# Or as heat content: `Th_tendency_vert_remap` (x,y,z) [W m

# %% [markdown]
# #### Temperature tendency
#
# [degC s-1]
#
# Tendency: `T_tendency` [x,y,z]

# %%
# Try to pull all of the terms together into one dataset
ds_budget = xr.merge([ds.thetao, ds.T_tendency, ds.rlntds, ds.rsdo, ds.hfsso, ds.hflso])

# %%
s = ds_budget.isel(zi=0)
s
# Out:
# <xarray.Dataset>
# Dimensions:     (time: 1, xh: 720, yh: 576, zl: 75)
# Coordinates:
#   * xh          (xh) float64 -299.8 -299.2 -298.8 -298.2 ... 58.75 59.25 59.75
#   * yh          (yh) float64 -77.91 -77.72 -77.54 -77.36 ... 89.47 89.68 89.89
#   * zl          (zl) float64 1.0 3.0 5.0 7.0 ... 3.338e+03 3.591e+03 5.111e+03
#   * time        (time) object 0946-01-01 00:00:00
#     zi          float64 0.0
# Data variables:
#     thetao      (time, zl, yh, xh) float32 ...
#     T_tendency  (time, zl, yh, xh) float32 ...
#     rlntds      (time, yh, xh) float32 ...
#     rsdo        (time, yh, xh) float32 ...
#     hfsso       (time, yh, xh) float32 ...
#     hflso       (time, yh, xh) float32 ...

# %%
hflx = s.rlntds+s.rsdo+s.hfsso+s.hflso
hflx.plot()

# %%
ds.hfrainds
# Out:
# <xarray.DataArray 'hfrainds' (time: 1, yh: 576, xh: 720)>
# [414720 values with dtype=float32]
# Coordinates:
#   * xh       (xh) float64 -299.8 -299.2 -298.8 -298.2 ... 58.75 59.25 59.75
#   * yh       (yh) float64 -77.91 -77.72 -77.54 -77.36 ... 89.47 89.68 89.89
#   * time     (time) object 0946-01-01 00:00:00
# Attributes:
#     long_name:      Heat content (relative to 0degC) of liquid+frozen precip ...
#     units:          W m-2
#     cell_measures:  area: areacello
#     standard_name:  temperature_flux_due_to_rainfall_expressed_as_heat_flux_i...
#     cell_methods:   area:mean yh:mean xh:mean time: mean
#     time_avg_info:  average_T1,average_T2,average_DT

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import xarray as xr
from xgcm import Grid
import glob
import matplotlib.pyplot as plt
import gsw
import os

# %%
# Load grid data and establish parameters for xgcm grid object
rootdir = '/home/gmacgilchrist/data/ECCO/'
filename = 'ECCO-GRID.nc'
grid = xr.open_dataset(rootdir+filename)
# Define the connectivity between faces
face_connections = {'face':
                    {0: {'X':  ((12, 'Y', False), (3, 'X', False)),
                         'Y':  (None,             (1, 'Y', False))},
                     1: {'X':  ((11, 'Y', False), (4, 'X', False)),
                         'Y':  ((0, 'Y', False),  (2, 'Y', False))},
                     2: {'X':  ((10, 'Y', False), (5, 'X', False)),
                         'Y':  ((1, 'Y', False),  (6, 'X', False))},
                     3: {'X':  ((0, 'X', False),  (9, 'Y', False)),
                         'Y':  (None,             (4, 'Y', False))},
                     4: {'X':  ((1, 'X', False),  (8, 'Y', False)),
                         'Y':  ((3, 'Y', False),  (5, 'Y', False))},
                     5: {'X':  ((2, 'X', False),  (7, 'Y', False)),
                         'Y':  ((4, 'Y', False),  (6, 'Y', False))},
                     6: {'X':  ((2, 'Y', False),  (7, 'X', False)),
                         'Y':  ((5, 'Y', False),  (10, 'X', False))},
                     7: {'X':  ((6, 'X', False),  (8, 'X', False)),
                         'Y':  ((5, 'X', False),  (10, 'Y', False))},
                     8: {'X':  ((7, 'X', False),  (9, 'X', False)),
                         'Y':  ((4, 'X', False),  (11, 'Y', False))},
                     9: {'X':  ((8, 'X', False),  None),
                         'Y':  ((3, 'X', False),  (12, 'Y', False))},
                     10: {'X': ((6, 'Y', False),  (11, 'X', False)),
                          'Y': ((7, 'Y', False),  (2, 'X', False))},
                     11: {'X': ((10, 'X', False), (12, 'X', False)),
                          'Y': ((8, 'Y', False),  (1, 'X', False))},
                     12: {'X': ((11, 'X', False), None),
                          'Y': ((9, 'Y', False),  (0, 'X', False))}}}

# Define vertical metrics as negative, to account for descending coordinate
grid['drW'] = -1 * grid.hFacW * grid.drF #vertical cell size at u point
grid['drS'] = -1 * grid.hFacS * grid.drF #vertical cell size at v point
grid['drC'] = -1 * grid.hFacC * grid.drF #vertical cell size at tracer point

metrics = {
    ('X',): ['dxC', 'dxG'], # X distances
    ('Y',): ['dyC', 'dyG'], # Y distances
    ('Z',): ['drW', 'drS', 'drC'], # Z distances
    ('X', 'Y'): ['rA', 'rAz', 'rAs', 'rAw'] # Areas
}

# %%
def _dhorz(ds,xgrid,var,mask=None):
    '''Take horizontal gradient of scalar field given by var.
    Return dictionary of horizontal gradient in each direction.'''
    
    if mask is not None:
        ds[var] = ds[var].where(ds[mask],np.nan)
    
    gx = xgrid.interp(ds[var], 'X')
    gy = xgrid.interp(ds[var], 'Y', boundary='fill')
    dg = xgrid.diff_2d_vector({'X':gx,'Y':gy},boundary='fill')
    
    D = xgrid.interp_2d_vector({'X':xgrid.get_metric(gx,'X'),'Y':xgrid.get_metric(gy,'Y')},boundary='fill')
    
    return {'X':dg['X']/D['X'],'Y':dg['Y']/D['Y']}

def _dvert(ds,xgrid,var):
    gz = xgrid.interp(ds[var],'Z',boundary='extrapolate')
    dgdz = xgrid.derivative(gz,'Z',boundary='extrapolate')
    return dgdz

def grad(ds,xgrid,var,mask=None):
    dC=_dhorz(ds,xgrid,var,mask)
    dC['Z']=_dvert(ds,xgrid,var)
    return dC

def grad_TSg(ds,xgrid):
    dT = grad(ds,xgrid,var='THETA',mask='maskC')
    dS = grad(ds,xgrid,var='SALT',mask='maskC')
    dg = grad(ds,xgrid,var='GAMMAN',mask='maskC')
    return dT, dS, dg
    
def grad_R(dT,dS,ds):
    alpha = gsw.alpha(ds['SALT'],ds['THETA'],ds['Z'])
    beta = gsw.beta(ds['SALT'],ds['THETA'],ds['Z'])

    rho0 = 1024.5
    dR = {}
    dR['X'] = rho0*(-alpha*dT['X'] + beta*dS['X'])
    dR['Y'] = rho0*(-alpha*dT['Y'] + beta*dS['Y'])
    dR['Z'] = rho0*(-alpha*dT['Z'] + beta*dS['Z'])
    
    return dR

def absgrad(dC):
    return xr.ufuncs.sqrt(xr.ufuncs.square(dC['X'])+
                          xr.ufuncs.square(dC['Y'])+
                          xr.ufuncs.square(dC['Z']))

def calc_bfactor(ds,xgrid):
    dT,dS,dg = grad_TSg(ds,xgrid)
    dR = grad_R(dT,dS,ds)
    absgradR = absgrad(dR)
    absgradg = absgrad(dg)
    return absgradg/absgradR

# %%
# Writing it as a for loop for ease of saving (consistency with other
# ECCO output)
rootdir = '/data2/project/ECCO4v4/'
outdir = '/data2/project/macgilchrist/ECCO4v4/'
years = np.arange(1992,2018)
months = np.arange(1,13)
for year in years:
    for month in months:
        print('Year is '+str(year)+'; month is '+str(month)+'.')
        gammain = rootdir+'GAMMAN/'+str(year)+'/GAMMAN_'+str(year)+'_'+str(month).zfill(2)+'.nc'
        thetain = rootdir+'nctiles_monthly/THETA/'+str(year)+'/THETA_'+str(year)+'_'+str(month).zfill(2)+'.nc'
        saltin = rootdir+'nctiles_monthly/SALT/'+str(year)+'/SALT_'+str(year)+'_'+str(month).zfill(2)+'.nc'
        
        gamma = xr.open_dataset(gammain)
        theta = xr.open_dataset(thetain)
        salt = xr.open_dataset(saltin)
        
        ds = xr.merge([gamma,theta,salt,grid]).rename({'tile':'face'})
        # Create the grid object for this dataset
        xgrid = Grid(ds, periodic=False, face_connections=face_connections, metrics=metrics)

        b = calc_bfactor(ds,xgrid)
        b.name = 'BFACTOR'
        if not os.path.isdir(outdir+'BFACTOR/'+str(year)):
            print('Eeep!')
            os.mkdir(outdir+'BFACTOR/'+str(year))
        bout = outdir+'BFACTOR/'+str(year)+'/BFACTOR_'+str(year)+'_'+str(month).zfill(2)+'.nc'
        print('Saving to '+bout)
        b.to_netcdf(bout)
# Out:
# Year is 1992; month is 1.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1992/BFACTOR_1992_01.nc
# Year is 1992; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1992/BFACTOR_1992_02.nc
# Year is 1992; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1992/BFACTOR_1992_03.nc
# Year is 1992; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1992/BFACTOR_1992_04.nc
# Year is 1992; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1992/BFACTOR_1992_05.nc
# Year is 1992; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1992/BFACTOR_1992_06.nc
# Year is 1992; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1992/BFACTOR_1992_07.nc
# Year is 1992; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1992/BFACTOR_1992_08.nc
# Year is 1992; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1992/BFACTOR_1992_09.nc
# Year is 1992; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1992/BFACTOR_1992_10.nc
# Year is 1992; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1992/BFACTOR_1992_11.nc
# Year is 1992; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1992/BFACTOR_1992_12.nc
# Year is 1993; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1993/BFACTOR_1993_01.nc
# Year is 1993; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1993/BFACTOR_1993_02.nc
# Year is 1993; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1993/BFACTOR_1993_03.nc
# Year is 1993; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1993/BFACTOR_1993_04.nc
# Year is 1993; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1993/BFACTOR_1993_05.nc
# Year is 1993; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1993/BFACTOR_1993_06.nc
# Year is 1993; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1993/BFACTOR_1993_07.nc
# Year is 1993; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1993/BFACTOR_1993_08.nc
# Year is 1993; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1993/BFACTOR_1993_09.nc
# Year is 1993; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1993/BFACTOR_1993_10.nc
# Year is 1993; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1993/BFACTOR_1993_11.nc
# Year is 1993; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1993/BFACTOR_1993_12.nc
# Year is 1994; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1994/BFACTOR_1994_01.nc
# Year is 1994; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1994/BFACTOR_1994_02.nc
# Year is 1994; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1994/BFACTOR_1994_03.nc
# Year is 1994; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1994/BFACTOR_1994_04.nc
# Year is 1994; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1994/BFACTOR_1994_05.nc
# Year is 1994; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1994/BFACTOR_1994_06.nc
# Year is 1994; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1994/BFACTOR_1994_07.nc
# Year is 1994; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1994/BFACTOR_1994_08.nc
# Year is 1994; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1994/BFACTOR_1994_09.nc
# Year is 1994; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1994/BFACTOR_1994_10.nc
# Year is 1994; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1994/BFACTOR_1994_11.nc
# Year is 1994; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1994/BFACTOR_1994_12.nc
# Year is 1995; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1995/BFACTOR_1995_01.nc
# Year is 1995; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1995/BFACTOR_1995_02.nc
# Year is 1995; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1995/BFACTOR_1995_03.nc
# Year is 1995; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1995/BFACTOR_1995_04.nc
# Year is 1995; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1995/BFACTOR_1995_05.nc
# Year is 1995; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1995/BFACTOR_1995_06.nc
# Year is 1995; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1995/BFACTOR_1995_07.nc
# Year is 1995; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1995/BFACTOR_1995_08.nc
# Year is 1995; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1995/BFACTOR_1995_09.nc
# Year is 1995; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1995/BFACTOR_1995_10.nc
# Year is 1995; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1995/BFACTOR_1995_11.nc
# Year is 1995; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1995/BFACTOR_1995_12.nc
# Year is 1996; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1996/BFACTOR_1996_01.nc
# Year is 1996; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1996/BFACTOR_1996_02.nc
# Year is 1996; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1996/BFACTOR_1996_03.nc
# Year is 1996; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1996/BFACTOR_1996_04.nc
# Year is 1996; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1996/BFACTOR_1996_05.nc
# Year is 1996; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1996/BFACTOR_1996_06.nc
# Year is 1996; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1996/BFACTOR_1996_07.nc
# Year is 1996; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1996/BFACTOR_1996_08.nc
# Year is 1996; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1996/BFACTOR_1996_09.nc
# Year is 1996; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1996/BFACTOR_1996_10.nc
# Year is 1996; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1996/BFACTOR_1996_11.nc
# Year is 1996; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1996/BFACTOR_1996_12.nc
# Year is 1997; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1997/BFACTOR_1997_01.nc
# Year is 1997; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1997/BFACTOR_1997_02.nc
# Year is 1997; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1997/BFACTOR_1997_03.nc
# Year is 1997; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1997/BFACTOR_1997_04.nc
# Year is 1997; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1997/BFACTOR_1997_05.nc
# Year is 1997; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1997/BFACTOR_1997_06.nc
# Year is 1997; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1997/BFACTOR_1997_07.nc
# Year is 1997; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1997/BFACTOR_1997_08.nc
# Year is 1997; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1997/BFACTOR_1997_09.nc
# Year is 1997; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1997/BFACTOR_1997_10.nc
# Year is 1997; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1997/BFACTOR_1997_11.nc
# Year is 1997; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1997/BFACTOR_1997_12.nc
# Year is 1998; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1998/BFACTOR_1998_01.nc
# Year is 1998; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1998/BFACTOR_1998_02.nc
# Year is 1998; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1998/BFACTOR_1998_03.nc
# Year is 1998; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1998/BFACTOR_1998_04.nc
# Year is 1998; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1998/BFACTOR_1998_05.nc
# Year is 1998; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1998/BFACTOR_1998_06.nc
# Year is 1998; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1998/BFACTOR_1998_07.nc
# Year is 1998; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1998/BFACTOR_1998_08.nc
# Year is 1998; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1998/BFACTOR_1998_09.nc
# Year is 1998; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1998/BFACTOR_1998_10.nc
# Year is 1998; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1998/BFACTOR_1998_11.nc
# Year is 1998; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1998/BFACTOR_1998_12.nc
# Year is 1999; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1999/BFACTOR_1999_01.nc
# Year is 1999; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1999/BFACTOR_1999_02.nc
# Year is 1999; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1999/BFACTOR_1999_03.nc
# Year is 1999; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1999/BFACTOR_1999_04.nc
# Year is 1999; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1999/BFACTOR_1999_05.nc
# Year is 1999; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1999/BFACTOR_1999_06.nc
# Year is 1999; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1999/BFACTOR_1999_07.nc
# Year is 1999; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1999/BFACTOR_1999_08.nc
# Year is 1999; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1999/BFACTOR_1999_09.nc
# Year is 1999; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1999/BFACTOR_1999_10.nc
# Year is 1999; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1999/BFACTOR_1999_11.nc
# Year is 1999; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/1999/BFACTOR_1999_12.nc
# Year is 2000; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2000/BFACTOR_2000_01.nc
# Year is 2000; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2000/BFACTOR_2000_02.nc
# Year is 2000; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2000/BFACTOR_2000_03.nc
# Year is 2000; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2000/BFACTOR_2000_04.nc
# Year is 2000; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2000/BFACTOR_2000_05.nc
# Year is 2000; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2000/BFACTOR_2000_06.nc
# Year is 2000; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2000/BFACTOR_2000_07.nc
# Year is 2000; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2000/BFACTOR_2000_08.nc
# Year is 2000; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2000/BFACTOR_2000_09.nc
# Year is 2000; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2000/BFACTOR_2000_10.nc
# Year is 2000; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2000/BFACTOR_2000_11.nc
# Year is 2000; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2000/BFACTOR_2000_12.nc
# Year is 2001; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2001/BFACTOR_2001_01.nc
# Year is 2001; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2001/BFACTOR_2001_02.nc
# Year is 2001; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2001/BFACTOR_2001_03.nc
# Year is 2001; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2001/BFACTOR_2001_04.nc
# Year is 2001; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2001/BFACTOR_2001_05.nc
# Year is 2001; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2001/BFACTOR_2001_06.nc
# Year is 2001; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2001/BFACTOR_2001_07.nc
# Year is 2001; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2001/BFACTOR_2001_08.nc
# Year is 2001; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2001/BFACTOR_2001_09.nc
# Year is 2001; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2001/BFACTOR_2001_10.nc
# Year is 2001; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2001/BFACTOR_2001_11.nc
# Year is 2001; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2001/BFACTOR_2001_12.nc
# Year is 2002; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2002/BFACTOR_2002_01.nc
# Year is 2002; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2002/BFACTOR_2002_02.nc
# Year is 2002; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2002/BFACTOR_2002_03.nc
# Year is 2002; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2002/BFACTOR_2002_04.nc
# Year is 2002; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2002/BFACTOR_2002_05.nc
# Year is 2002; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2002/BFACTOR_2002_06.nc
# Year is 2002; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2002/BFACTOR_2002_07.nc
# Year is 2002; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2002/BFACTOR_2002_08.nc
# Year is 2002; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2002/BFACTOR_2002_09.nc
# Year is 2002; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2002/BFACTOR_2002_10.nc
# Year is 2002; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2002/BFACTOR_2002_11.nc
# Year is 2002; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2002/BFACTOR_2002_12.nc
# Year is 2003; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2003/BFACTOR_2003_01.nc
# Year is 2003; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2003/BFACTOR_2003_02.nc
# Year is 2003; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2003/BFACTOR_2003_03.nc
# Year is 2003; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2003/BFACTOR_2003_04.nc
# Year is 2003; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2003/BFACTOR_2003_05.nc
# Year is 2003; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2003/BFACTOR_2003_06.nc
# Year is 2003; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2003/BFACTOR_2003_07.nc
# Year is 2003; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2003/BFACTOR_2003_08.nc
# Year is 2003; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2003/BFACTOR_2003_09.nc
# Year is 2003; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2003/BFACTOR_2003_10.nc
# Year is 2003; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2003/BFACTOR_2003_11.nc
# Year is 2003; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2003/BFACTOR_2003_12.nc
# Year is 2004; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2004/BFACTOR_2004_01.nc
# Year is 2004; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2004/BFACTOR_2004_02.nc
# Year is 2004; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2004/BFACTOR_2004_03.nc
# Year is 2004; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2004/BFACTOR_2004_04.nc
# Year is 2004; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2004/BFACTOR_2004_05.nc
# Year is 2004; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2004/BFACTOR_2004_06.nc
# Year is 2004; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2004/BFACTOR_2004_07.nc
# Year is 2004; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2004/BFACTOR_2004_08.nc
# Year is 2004; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2004/BFACTOR_2004_09.nc
# Year is 2004; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2004/BFACTOR_2004_10.nc
# Year is 2004; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2004/BFACTOR_2004_11.nc
# Year is 2004; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2004/BFACTOR_2004_12.nc
# Year is 2005; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2005/BFACTOR_2005_01.nc
# Year is 2005; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2005/BFACTOR_2005_02.nc
# Year is 2005; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2005/BFACTOR_2005_03.nc
# Year is 2005; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2005/BFACTOR_2005_04.nc
# Year is 2005; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2005/BFACTOR_2005_05.nc
# Year is 2005; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2005/BFACTOR_2005_06.nc
# Year is 2005; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2005/BFACTOR_2005_07.nc
# Year is 2005; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2005/BFACTOR_2005_08.nc
# Year is 2005; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2005/BFACTOR_2005_09.nc
# Year is 2005; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2005/BFACTOR_2005_10.nc
# Year is 2005; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2005/BFACTOR_2005_11.nc
# Year is 2005; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2005/BFACTOR_2005_12.nc
# Year is 2006; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2006/BFACTOR_2006_01.nc
# Year is 2006; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2006/BFACTOR_2006_02.nc
# Year is 2006; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2006/BFACTOR_2006_03.nc
# Year is 2006; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2006/BFACTOR_2006_04.nc
# Year is 2006; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2006/BFACTOR_2006_05.nc
# Year is 2006; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2006/BFACTOR_2006_06.nc
# Year is 2006; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2006/BFACTOR_2006_07.nc
# Year is 2006; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2006/BFACTOR_2006_08.nc
# Year is 2006; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2006/BFACTOR_2006_09.nc
# Year is 2006; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2006/BFACTOR_2006_10.nc
# Year is 2006; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2006/BFACTOR_2006_11.nc
# Year is 2006; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2006/BFACTOR_2006_12.nc
# Year is 2007; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2007/BFACTOR_2007_01.nc
# Year is 2007; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2007/BFACTOR_2007_02.nc
# Year is 2007; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2007/BFACTOR_2007_03.nc
# Year is 2007; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2007/BFACTOR_2007_04.nc
# Year is 2007; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2007/BFACTOR_2007_05.nc
# Year is 2007; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2007/BFACTOR_2007_06.nc
# Year is 2007; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2007/BFACTOR_2007_07.nc
# Year is 2007; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2007/BFACTOR_2007_08.nc
# Year is 2007; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2007/BFACTOR_2007_09.nc
# Year is 2007; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2007/BFACTOR_2007_10.nc
# Year is 2007; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2007/BFACTOR_2007_11.nc
# Year is 2007; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2007/BFACTOR_2007_12.nc
# Year is 2008; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2008/BFACTOR_2008_01.nc
# Year is 2008; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2008/BFACTOR_2008_02.nc
# Year is 2008; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2008/BFACTOR_2008_03.nc
# Year is 2008; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2008/BFACTOR_2008_04.nc
# Year is 2008; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2008/BFACTOR_2008_05.nc
# Year is 2008; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2008/BFACTOR_2008_06.nc
# Year is 2008; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2008/BFACTOR_2008_07.nc
# Year is 2008; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2008/BFACTOR_2008_08.nc
# Year is 2008; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2008/BFACTOR_2008_09.nc
# Year is 2008; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2008/BFACTOR_2008_10.nc
# Year is 2008; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2008/BFACTOR_2008_11.nc
# Year is 2008; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2008/BFACTOR_2008_12.nc
# Year is 2009; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2009/BFACTOR_2009_01.nc
# Year is 2009; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2009/BFACTOR_2009_02.nc
# Year is 2009; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2009/BFACTOR_2009_03.nc
# Year is 2009; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2009/BFACTOR_2009_04.nc
# Year is 2009; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2009/BFACTOR_2009_05.nc
# Year is 2009; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2009/BFACTOR_2009_06.nc
# Year is 2009; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2009/BFACTOR_2009_07.nc
# Year is 2009; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2009/BFACTOR_2009_08.nc
# Year is 2009; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2009/BFACTOR_2009_09.nc
# Year is 2009; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2009/BFACTOR_2009_10.nc
# Year is 2009; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2009/BFACTOR_2009_11.nc
# Year is 2009; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2009/BFACTOR_2009_12.nc
# Year is 2010; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2010/BFACTOR_2010_01.nc
# Year is 2010; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2010/BFACTOR_2010_02.nc
# Year is 2010; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2010/BFACTOR_2010_03.nc
# Year is 2010; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2010/BFACTOR_2010_04.nc
# Year is 2010; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2010/BFACTOR_2010_05.nc
# Year is 2010; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2010/BFACTOR_2010_06.nc
# Year is 2010; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2010/BFACTOR_2010_07.nc
# Year is 2010; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2010/BFACTOR_2010_08.nc
# Year is 2010; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2010/BFACTOR_2010_09.nc
# Year is 2010; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2010/BFACTOR_2010_10.nc
# Year is 2010; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2010/BFACTOR_2010_11.nc
# Year is 2010; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2010/BFACTOR_2010_12.nc
# Year is 2011; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2011/BFACTOR_2011_01.nc
# Year is 2011; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2011/BFACTOR_2011_02.nc
# Year is 2011; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2011/BFACTOR_2011_03.nc
# Year is 2011; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2011/BFACTOR_2011_04.nc
# Year is 2011; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2011/BFACTOR_2011_05.nc
# Year is 2011; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2011/BFACTOR_2011_06.nc
# Year is 2011; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2011/BFACTOR_2011_07.nc
# Year is 2011; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2011/BFACTOR_2011_08.nc
# Year is 2011; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2011/BFACTOR_2011_09.nc
# Year is 2011; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2011/BFACTOR_2011_10.nc
# Year is 2011; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2011/BFACTOR_2011_11.nc
# Year is 2011; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2011/BFACTOR_2011_12.nc
# Year is 2012; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2012/BFACTOR_2012_01.nc
# Year is 2012; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2012/BFACTOR_2012_02.nc
# Year is 2012; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2012/BFACTOR_2012_03.nc
# Year is 2012; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2012/BFACTOR_2012_04.nc
# Year is 2012; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2012/BFACTOR_2012_05.nc
# Year is 2012; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2012/BFACTOR_2012_06.nc
# Year is 2012; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2012/BFACTOR_2012_07.nc
# Year is 2012; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2012/BFACTOR_2012_08.nc
# Year is 2012; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2012/BFACTOR_2012_09.nc
# Year is 2012; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2012/BFACTOR_2012_10.nc
# Year is 2012; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2012/BFACTOR_2012_11.nc
# Year is 2012; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2012/BFACTOR_2012_12.nc
# Year is 2013; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2013/BFACTOR_2013_01.nc
# Year is 2013; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2013/BFACTOR_2013_02.nc
# Year is 2013; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2013/BFACTOR_2013_03.nc
# Year is 2013; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2013/BFACTOR_2013_04.nc
# Year is 2013; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2013/BFACTOR_2013_05.nc
# Year is 2013; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2013/BFACTOR_2013_06.nc
# Year is 2013; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2013/BFACTOR_2013_07.nc
# Year is 2013; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2013/BFACTOR_2013_08.nc
# Year is 2013; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2013/BFACTOR_2013_09.nc
# Year is 2013; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2013/BFACTOR_2013_10.nc
# Year is 2013; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2013/BFACTOR_2013_11.nc
# Year is 2013; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2013/BFACTOR_2013_12.nc
# Year is 2014; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2014/BFACTOR_2014_01.nc
# Year is 2014; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2014/BFACTOR_2014_02.nc
# Year is 2014; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2014/BFACTOR_2014_03.nc
# Year is 2014; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2014/BFACTOR_2014_04.nc
# Year is 2014; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2014/BFACTOR_2014_05.nc
# Year is 2014; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2014/BFACTOR_2014_06.nc
# Year is 2014; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2014/BFACTOR_2014_07.nc
# Year is 2014; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2014/BFACTOR_2014_08.nc
# Year is 2014; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2014/BFACTOR_2014_09.nc
# Year is 2014; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2014/BFACTOR_2014_10.nc
# Year is 2014; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2014/BFACTOR_2014_11.nc
# Year is 2014; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2014/BFACTOR_2014_12.nc
# Year is 2015; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2015/BFACTOR_2015_01.nc
# Year is 2015; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2015/BFACTOR_2015_02.nc
# Year is 2015; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2015/BFACTOR_2015_03.nc
# Year is 2015; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2015/BFACTOR_2015_04.nc
# Year is 2015; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2015/BFACTOR_2015_05.nc
# Year is 2015; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2015/BFACTOR_2015_06.nc
# Year is 2015; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2015/BFACTOR_2015_07.nc
# Year is 2015; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2015/BFACTOR_2015_08.nc
# Year is 2015; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2015/BFACTOR_2015_09.nc
# Year is 2015; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2015/BFACTOR_2015_10.nc
# Year is 2015; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2015/BFACTOR_2015_11.nc
# Year is 2015; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2015/BFACTOR_2015_12.nc
# Year is 2016; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2016/BFACTOR_2016_01.nc
# Year is 2016; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2016/BFACTOR_2016_02.nc
# Year is 2016; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2016/BFACTOR_2016_03.nc
# Year is 2016; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2016/BFACTOR_2016_04.nc
# Year is 2016; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2016/BFACTOR_2016_05.nc
# Year is 2016; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2016/BFACTOR_2016_06.nc
# Year is 2016; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2016/BFACTOR_2016_07.nc
# Year is 2016; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2016/BFACTOR_2016_08.nc
# Year is 2016; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2016/BFACTOR_2016_09.nc
# Year is 2016; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2016/BFACTOR_2016_10.nc
# Year is 2016; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2016/BFACTOR_2016_11.nc
# Year is 2016; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2016/BFACTOR_2016_12.nc
# Year is 2017; month is 1.
# Eeep!
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2017/BFACTOR_2017_01.nc
# Year is 2017; month is 2.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2017/BFACTOR_2017_02.nc
# Year is 2017; month is 3.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2017/BFACTOR_2017_03.nc
# Year is 2017; month is 4.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2017/BFACTOR_2017_04.nc
# Year is 2017; month is 5.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2017/BFACTOR_2017_05.nc
# Year is 2017; month is 6.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2017/BFACTOR_2017_06.nc
# Year is 2017; month is 7.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2017/BFACTOR_2017_07.nc
# Year is 2017; month is 8.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2017/BFACTOR_2017_08.nc
# Year is 2017; month is 9.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2017/BFACTOR_2017_09.nc
# Year is 2017; month is 10.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2017/BFACTOR_2017_10.nc
# Year is 2017; month is 11.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2017/BFACTOR_2017_11.nc
# Year is 2017; month is 12.
# Saving to /data2/project/macgilchrist/ECCO4v4/BFACTOR/2017/BFACTOR_2017_12.nc
